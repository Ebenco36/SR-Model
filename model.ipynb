# %%
# !python -m src.SR.data_generation.ner_extractor --corpus infectious_disease_papers --out dataset_scaffold/infection_ner_llm.jsonl --llm --model llama3.1:8b --verbose
# Out:
# 2025-12-18 00:00:25,584 - DEBUG - Verbose logging enabled
# 2025-12-18 00:00:25,584 - INFO - ======================================================================
# 2025-12-18 00:00:25,584 - INFO - NER EXTRACTION PIPELINE - 55 ENTITY TYPES
# 2025-12-18 00:00:25,584 - INFO - ======================================================================
# 2025-12-18 00:00:25,585 - INFO - Corpus: /Users/awotoroebenezer/Desktop/SenseBackend/infectious_disease_papers
# 2025-12-18 00:00:25,585 - INFO - Output: /Users/awotoroebenezer/Desktop/SenseBackend/dataset_scaffold/infection_ner_llm.jsonl
# 2025-12-18 00:00:25,585 - INFO - LLM: Enabled
# 2025-12-18 00:00:25,585 - INFO - Workers: 1
# 2025-12-18 00:00:25,585 - INFO - Resume: False
# 2025-12-18 00:00:25,585 - INFO - Total entity types: 55
# 2025-12-18 00:00:25,585 - INFO - ======================================================================
# 2025-12-18 00:00:25,585 - INFO - Found 3 text files
# ...

# %%
# !python -m src.SR.data_generation.qa_generator --ner dataset_scaffold/infection_ner_llm.jsonl --output qa_dataset
# Out:
# 2025-12-18 00:15:07,503 - INFO - ============================================================
# 2025-12-18 00:15:07,503 - INFO - QA DATASET GENERATION
# 2025-12-18 00:15:07,503 - INFO - ============================================================
# 2025-12-18 00:15:07,503 - INFO - Input NER file: /Users/awotoroebenezer/Desktop/SenseBackend/dataset_scaffold/infection_ner_llm.jsonl
# 2025-12-18 00:15:07,503 - INFO - Output directory: /Users/awotoroebenezer/Desktop/SenseBackend/qa_dataset
# 2025-12-18 00:15:07,503 - INFO - Train/Val/Test split: 0.70/0.15/0.15
# 2025-12-18 00:15:07,503 - INFO - Random seed: 42
# 2025-12-18 00:15:07,503 - INFO - ============================================================
# 2025-12-18 00:15:07,504 - INFO - Loaded 3 NER results from dataset_scaffold/infection_ner_llm.jsonl
# 2025-12-18 00:15:07,504 - INFO - Generated 12 QA pairs for paper1
# 2025-12-18 00:15:07,504 - INFO - Generated 5 QA pairs for paper2
# ...

# %%
# Check what was created
# !ls -la qa_dataset/

# View dataset statistics
# !cat qa_dataset/dataset_statistics.json | python -m json.tool

# Check sample QA pairs
# !head -5 qa_dataset/train/train.json | python -m json.tool

# !head -5 qa_dataset/train/train.json | python -m json.tool
# Out:
# total 8
# drwxr-xr-x@  6 awotoroebenezer  staff   192 Dec 18 00:15 .
# drwxr-xr-x@ 56 awotoroebenezer  staff  1792 Dec 18 00:15 ..
# -rw-r--r--@  1 awotoroebenezer  staff   727 Dec 18 00:15 dataset_statistics.json
# drwxr-xr-x@  4 awotoroebenezer  staff   128 Dec 18 00:15 test
# drwxr-xr-x@  4 awotoroebenezer  staff   128 Dec 18 00:15 train
# drwxr-xr-x@  4 awotoroebenezer  staff   128 Dec 18 00:15 validation
# {
#     "qa_pairs_generated": 23,
#     "qa_REVIEW_TYPE": 3,
#     "qa_REGION": 1,
#     "qa_N_STUDIES": 2,
#     "qa_RISK_GROUP": 1,
#     "qa_PERCENT": 2,
#     "qa_CI": 2,
#     "qa_SEARCH_TERMS": 1,
#     "qa_DATABASE": 1,
#     "qa_DATE_OF_LAST_LITERATURE_SEARCH": 1,
#     "qa_SAMPLE_SIZE": 1,
#     "qa_COUNTRY": 2,
#     "qa_STUDY_DESIGN": 1,
#     "documents_processed": 3,
#     "total_qa_pairs": 23,
#     "qa_PATHOGEN": 2,
#     "qa_PROGRAM": 1,
#     "qa_COVERAGE": 1,
#     "qa_EFFECT_MEASURE": 1,
#     "total_examples": 23,
#     "train_examples": 16,
# ...

# %%
# !python -m src.SR.data_generation.qa_generator --validate qa_dataset/train/train.jsonl
# Out:
# 2025-12-18 00:21:52,451 - INFO - Validating QA dataset: qa_dataset/train/train.jsonl
# 2025-12-18 00:21:52,452 - INFO -
# ...
# 2025-12-18 00:21:52,452 - INFO - VALIDATION RESULTS
# 2025-12-18 00:21:52,452 - INFO - ============================================================
# 2025-12-18 00:21:52,452 - INFO - Total examples: 16
# 2025-12-18 00:21:52,452 - INFO - Valid examples: 16 (100.0%)
# 2025-12-18 00:21:52,452 - INFO - Invalid examples: 0 (0.0%)
# 2025-12-18 00:21:52,452 - INFO -
# Label distribution (top 10):
# 2025-12-18 00:21:52,452 - INFO -   COUNTRY: 2
# 2025-12-18 00:21:52,452 - INFO -   N_STUDIES: 2
# 2025-12-18 00:21:52,452 - INFO -   CI: 2
# 2025-12-18 00:21:52,452 - INFO -   REVIEW_TYPE: 2
# 2025-12-18 00:21:52,452 - INFO -   PERCENT: 1
# 2025-12-18 00:21:52,452 - INFO -   PATHOGEN: 1
# 2025-12-18 00:21:52,452 - INFO -   SEARCH_TERMS: 1
# 2025-12-18 00:21:52,452 - INFO -   SAMPLE_SIZE: 1
# 2025-12-18 00:21:52,452 - INFO -   REGION: 1
# ...

# %%
# !python -m src.SR.model_run --qa-dataset qa_dataset/ --output results/
# Out:
# ...
# ROBUST HARDWARE-AGNOSTIC MODEL COMPARISON
# ...
# Models to compare: 5
# Output directory: results/
# Epochs: 3
# Test samples: 1000
# ...
#
# MPS optimizations applied
# 2025-12-18 01:07:00,852 - __main__ - INFO - ================================================================================
# 2025-12-18 01:07:00,852 - __main__ - INFO - HARDWARE DETECTION & OPTIMIZATION
# 2025-12-18 01:07:00,852 - __main__ - INFO - ================================================================================
# 2025-12-18 01:07:00,852 - __main__ - INFO - System: Darwin macOS-15.4.1-arm64-arm-64bit
# 2025-12-18 01:07:00,852 - __main__ - INFO - Processor: arm
# 2025-12-18 01:07:00,852 - __main__ - INFO - CPU Cores: 14
# 2025-12-18 01:07:00,852 - __main__ - INFO - RAM: 24.0 GB
# 2025-12-18 01:07:00,852 - __main__ - INFO - Available RAM: 5.8 GB
# 2025-12-18 01:07:00,852 - __main__ - INFO - Selected Device: MPS (Apple Silicon)
# ...
